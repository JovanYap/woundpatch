# %% [markdown]
# # WoundPatch batch demo
# Run detection on all images in `./dataset/val` and display the compare outputs.

# %%
from pathlib import Path
from IPython.display import Image, display

from woundpatch import process_image

dataset_dir = Path("dataset/val")
output_dir = Path("outputs/gmm")
bandage_path = None  # set to a PNG with alpha if desired
wound_mode = "gmm"

image_paths = sorted([
    *dataset_dir.glob("*.jpg"),
    *dataset_dir.glob("*.jpeg"),
    *dataset_dir.glob("*.png")
])

print(f"Found {len(image_paths)} images in {dataset_dir}")
# Out:
# Found 17 images in dataset/val

# %%
import os
import cv2
import matplotlib.pyplot as plt
for image_path in image_paths:
    process_image(
        str(image_path),
        str(output_dir),
        bandage_path,
        show=False,
        wound_mode=wound_mode,
    )
# Out:
# Saved: outputs/gmm/abrasions (10)_bandaged_gmm.png
# Saved: outputs/gmm/abrasions (10)_compare_gmm.png
# Saved: outputs/gmm/abrasions (11)_bandaged_gmm.png
# Saved: outputs/gmm/abrasions (11)_compare_gmm.png
# Saved: outputs/gmm/abrasions (12)_bandaged_gmm.png
# Saved: outputs/gmm/abrasions (12)_compare_gmm.png
# Saved: outputs/gmm/abrasions (21)_bandaged_gmm.png
# Saved: outputs/gmm/abrasions (21)_compare_gmm.png
# Saved: outputs/gmm/abrasions (22)_bandaged_gmm.png
# Saved: outputs/gmm/abrasions (22)_compare_gmm.png
# Saved: outputs/gmm/abrasions (24)_bandaged_gmm.png
# Saved: outputs/gmm/abrasions (24)_compare_gmm.png
# Saved: outputs/gmm/abrasions (27)_bandaged_gmm.png
# Saved: outputs/gmm/abrasions (27)_compare_gmm.png
# Saved: outputs/gmm/abrasions (34)_bandaged_gmm.png
# Saved: outputs/gmm/abrasions (34)_compare_gmm.png
# Saved: outputs/gmm/abrasions (35)_bandaged_gmm.png
# Saved: outputs/gmm/abrasions (35)_compare_gmm.png
# Saved: outputs/gmm/abrasions (63)_bandaged_gmm.png
# Saved: outputs/gmm/abrasions (63)_compare_gmm.png
# No high-confidence wound detected for dataset/val/abrasions (79).jpg
# Saved: outputs/gmm/abrasions (79)_bandaged_gmm.png
# Saved: outputs/gmm/abrasions (79)_compare_gmm.png
# No high-confidence wound detected for dataset/val/cut (11).jpg
# Saved: outputs/gmm/cut (11)_bandaged_gmm.png
# Saved: outputs/gmm/cut (11)_compare_gmm.png
# No high-confidence wound detected for dataset/val/cut (13).jpg
# Saved: outputs/gmm/cut (13)_bandaged_gmm.png
# Saved: outputs/gmm/cut (13)_compare_gmm.png
# No high-confidence wound detected for dataset/val/cut (23).jpg
# Saved: outputs/gmm/cut (23)_bandaged_gmm.png
# Saved: outputs/gmm/cut (23)_compare_gmm.png
# Saved: outputs/gmm/cut (24)_bandaged_gmm.png
# Saved: outputs/gmm/cut (24)_compare_gmm.png
# No high-confidence wound detected for dataset/val/cut (4).jpg
# Saved: outputs/gmm/cut (4)_bandaged_gmm.png
# Saved: outputs/gmm/cut (4)_compare_gmm.png
# Saved: outputs/gmm/cut (6)_bandaged_gmm.png
# Saved: outputs/gmm/cut (6)_compare_gmm.png

# %%
image_dir = "/Users/jovanyap/Documents/woundpatch/outputs/gmm"
for filename in os.listdir(image_dir):
    if filename.lower().endswith((".png", ".jpg", ".jpeg")) and "compare" in filename:
        img_path = os.path.join(image_dir, filename)
        img = cv2.imread(img_path)

        if img is None:
            continue

        img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

        plt.figure(figsize=(6, 4))
        plt.imshow(img_rgb)
        plt.title(filename)
        plt.axis("off")
        plt.show()
