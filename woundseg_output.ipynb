# %% [markdown]
# # WoundPatch batch demo
# Run detection on all images in `./dataset/val` and display the compare outputs.

# %%
from pathlib import Path
from IPython.display import Image, display

from woundpatch import process_image

dataset_dir = Path("dataset/val")
output_dir = Path("outputs/woundseg")
bandage_path = None  # set to a PNG with alpha if desired
wound_mode = "woundseg"

image_paths = sorted([
    *dataset_dir.glob("*.jpg"),
    *dataset_dir.glob("*.jpeg"),
    *dataset_dir.glob("*.png")
])

print(f"Found {len(image_paths)} images in {dataset_dir}")
# Out:
# Found 17 images in dataset/val

# %%
import os
import cv2
import matplotlib.pyplot as plt
for image_path in image_paths:
    process_image(
        str(image_path),
        str(output_dir),
        bandage_path,
        show=False,
        wound_mode=wound_mode,
    )
# Out:
# WARNING:tensorflow:From /Users/jovanyap/Documents/woundpatch/.venv/lib/python3.11/site-packages/tensorflow/python/util/dispatch.py:1260: resize_bilinear (from tensorflow.python.ops.image_ops_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.image.resize(...method=ResizeMethod.BILINEAR...)` instead.
# Saved: outputs/woundseg/abrasions (10)_bandaged_woundseg.png
# Saved: outputs/woundseg/abrasions (10)_compare_woundseg.png
# Saved: outputs/woundseg/abrasions (11)_bandaged_woundseg.png
# Saved: outputs/woundseg/abrasions (11)_compare_woundseg.png
# No high-confidence wound detected for dataset/val/abrasions (12).jpg
# Saved: outputs/woundseg/abrasions (12)_bandaged_woundseg.png
# Saved: outputs/woundseg/abrasions (12)_compare_woundseg.png
# No high-confidence wound detected for dataset/val/abrasions (21).jpg
# Saved: outputs/woundseg/abrasions (21)_bandaged_woundseg.png
# Saved: outputs/woundseg/abrasions (21)_compare_woundseg.png
# ...

# %%
image_dir = "/Users/jovanyap/Documents/woundpatch/outputs/woundseg"
for filename in os.listdir(image_dir):
    if filename.lower().endswith((".png", ".jpg", ".jpeg")) and "compare" in filename:
        img_path = os.path.join(image_dir, filename)
        img = cv2.imread(img_path)

        if img is None:
            continue

        img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

        plt.figure(figsize=(6, 4))
        plt.imshow(img_rgb)
        plt.title(filename)
        plt.axis("off")
        plt.show()
